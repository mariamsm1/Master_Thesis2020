# %%
import numpy as np
import matplotlib.pyplot as plt

#Comparing Illumination corrected vs illumination uncorrected cells and nuclei upon evaluation

#Add the average F1 scores for each pipeline (with illumination correction and without illumination correction)

nuclei_with = [0.4816,0.5264,0.5747,0.5771,0.5811,0.5861,0.5906]
nuclei_without = [0.4881,0.5251,0.5735,0.5788,0.5829,0.5855,0.593]
cell_with = [0.4561,0.4636,0.4702,0.4758,0.4772,0.4852]
cell_without = [0.45,0.4522,0.4543,0.4572,0.4605,0.4736]

labels = ['Nuclei','Cells']
aver_nuclei= [sum(nuclei_with)/len(nuclei_with),sum(nuclei_without)/len(nuclei_without)]
aver_cell= [sum(cell_with)/len(cell_with),sum(cell_without)/len(cell_without)]
width = 0.1
r = [0.04,1.04]


fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
first_plot = ax.bar(np.arange(len(aver_nuclei)), [aver_nuclei[0],aver_cell[0]], width, color='royalblue', label = 'Illumination corrected')
first_plot = ax.bar(np.arange(len(aver_nuclei))+width, [aver_nuclei[1],aver_cell[1]], width, color='green', label = 'Illumination uncorrected')
plt.xticks(r, labels, rotation = 0)
plt.legend(loc='best')
plt.ylabel('Average F1 score');

# %%
import numpy as np
import matplotlib.pyplot as plt

#Comparing Illumination corrected vs illumination uncorrected cells and nuclei upon evaluation

import numpy as np
import matplotlib.pyplot as plt

#Add the average Jaccard index values for each pipeline (with illumination correction and without illumination correction)

nuclei_with = [0.7276,0.7499,0.7690,0.7797,0.7831,0.7842,0.7855]
nuclei_without = [0.7323,0.7499,0.7762,0.7760,0.7858,0.7845,0.7868]
cell_with = [0.7099,0.7068,0.7046,0.7034,0.6971,0.6937]
cell_without = [0.6955,0.6966,0.6943,0.7013,0.7019,0.7068]

labels = ['Nuclei','Cells']
aver_nuclei= [sum(nuclei_with)/len(nuclei_with),sum(nuclei_without)/len(nuclei_without)]
aver_cell= [sum(cell_with)/len(cell_with),sum(cell_without)/len(cell_without)]
width = 0.1
r = [0.04,1.04]


fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
first_plot = ax.bar(np.arange(len(aver_nuclei)), [aver_nuclei[0],aver_cell[0]], width, color='royalblue', label = 'Illumination corrected')
first_plot = ax.bar(np.arange(len(aver_nuclei))+width, [aver_nuclei[1],aver_cell[1]], width, color='green', label = 'Illumination uncorrected')
plt.xticks(r, labels, rotation = 0)
plt.legend(loc='best')
plt.ylabel('Average Jaccard index');
